# %%
print("surya")
# Out:
# surya

# %%
for i in range(1,20):
    print("Surya")
# Out:
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
# Surya
